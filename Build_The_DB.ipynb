# %%
# !pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.7-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from meteostat) (1.4.4)
# Requirement already satisfied: pytz in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from meteostat) (2022.1)
# Requirement already satisfied: numpy in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from meteostat) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.7

# %%
from meteostat import Point, Daily, Stations, Monthly
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path  
from tqdm import tqdm
import os
import geopandas as gpd

# %%
stations = Stations()
# PARAMETERS :
# Max Distance if a point is too far from any station :
distance_max = 100000
# Set time period :
start = datetime(1978, 1, 1)
end = datetime(2022, 12, 31)
# Create Points :
# MAT_x = np.arange(43.7, 50.4, 0.2)
MAT_x = np.arange(-60, 82, 1)
# MAT_y = np.arange(-4.5, 7.25, 0.2)
MAT_y = np.arange(-179, 180,1)
MAT = np.zeros((MAT_x.shape[0],MAT_y.shape[0], 2))
# print(MAT.shape)

# %%
## CREATION OF THE DB : (with all stations we are going to use)

for x in range(MAT_x.shape[0]):
    for y in range(MAT_y.shape[0]):
        MAT[x, y] = (MAT_x[x], MAT_y[y])
# print(MAT)

# Create Point for all points in MAT
col_names = stations.nearby(0, 0).fetch(1).columns
loc_df = pd.DataFrame(columns=col_names)
for elt in MAT:
    for elt_bis in elt:
        stations = stations.nearby(elt_bis[0], elt_bis[1])
        # station_data = 
        station_name = stations.fetch(1)
        station_name = station_name[col_names]
        # print(station_name)
        loc_df = pd.concat([loc_df, station_name], ignore_index=True)

dist_df = pd.DataFrame(columns=["name", "distance"])
dist_df = loc_df.loc[:,["name", "distance"]]
#print(dist_df)
dist_df = dist_df.groupby("name").min()
#print(dist_df)
loc_df.drop("distance", axis=1, inplace=True)
#print(loc_df)
loc_df.drop_duplicates(inplace=True)
#print(loc_df)
loc_df = loc_df.join(dist_df,on='name')
#print(loc_df)
loc_df.drop(loc_df[loc_df.distance > distance_max].index, inplace=True)
#print(loc_df)
loc_df.drop(loc_df[loc_df.daily_start > start].index, inplace=True)
loc_df.drop(loc_df[loc_df.daily_end < end].index, inplace=True)
#print(loc_df)
loc_df.drop(["hourly_start", "hourly_end", "daily_start", "daily_end"], axis=1, inplace=True)
loc_df.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 11>()
#      16         station_name = station_name[col_names]
#      17         # print(station_name)
# ---> 18         loc_df = pd.concat([loc_df, station_name], ignore_index=True)
#      20 dist_df = pd.DataFrame(columns=["name", "distance"])
#      21 dist_df = loc_df.loc[:,["name", "distance"]]
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/reshape/concat.py:595, in _Concatenator.get_result(self)
#     591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
# --> 595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#     598 if not self.copy:
#     599     new_data._consolidate_inplace()
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/internals/concat.py:235, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     232     values = np.concatenate(vals, axis=1)
#     233 else:
#     234     # TODO(EA2D): special-casing not needed with 2D EAs
# --> 235     values = concat_compat(vals, axis=1)
#     236     values = ensure_block_shape(values, ndim=2)
#     238 values = ensure_wrapped_if_datetimelike(values)
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/dtypes/concat.py:133, in concat_compat(to_concat, axis, ea_compat_axis)
#     130 if isinstance(to_concat[0], ABCExtensionArray):
#     131     # TODO: what about EA-backed Index?
#     132     cls = type(to_concat[0])
# --> 133     return cls._concat_same_type(to_concat)
#     134 else:
#     135     return np.concatenate(to_concat)
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py:214, in NDArrayBackedExtensionArray._concat_same_type(cls, to_concat, axis)
#     211 new_values = np.concatenate(new_values, axis=axis)
#     212 # error: Argument 1 to "_from_backing_data" of "NDArrayBackedExtensionArray" has
#     213 # incompatible type "List[ndarray]"; expected "ndarray"
# --> 214 return to_concat[0]._from_backing_data(new_values)
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/arrays/numpy_.py:116, in PandasArray._from_backing_data(self, arr)
#     115 def _from_backing_data(self, arr: np.ndarray) -> PandasArray:
# --> 116     return type(self)(arr)
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/arrays/string_.py:318, in StringArray.__init__(self, values, copy)
#     316 NDArrayBacked.__init__(self, self._ndarray, StringDtype(storage="python"))
#     317 if not isinstance(values, type(self)):
# --> 318     self._validate()
#
# File ~/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages/pandas/core/arrays/string_.py:322, in StringArray._validate(self)
#     320 def _validate(self):
#     321     """Validate that we only store NA or strings."""
# --> 322     if len(self._ndarray) and not lib.is_string_array(self._ndarray, skipna=True):
#     323         raise ValueError("StringArray requires a sequence of strings or pandas.NA")
#     324     if self._ndarray.dtype != "object":
#
# KeyboardInterrupt:

# %%
lati_list = list(loc_df["latitude"])
long_list = list(loc_df["longitude"])
loc_df
# Out:
#                        name country region    wmo  icao  latitude  longitude  \
# 328       Macquarie Island*      AU    TAS  94998  YMMQ  -54.5000   158.9000
# 733          Chatham Island      NZ     CI  93986  NZCI  -43.9500  -176.5667
# 1535           Punta Arenas      CL     MA  85934  SCCI  -53.0000   -70.8500
# 1903      Ushuaia Aerodrome      AR      V  87938  SAWH  -54.8000   -68.3167
# 2264       Rio Grande B. A.      AR      V  87934  SAWE  -53.8000   -67.7500
# ...                     ...     ...    ...    ...   ...       ...        ...
# 48186  Resolute Bay Airport      CA     NU  71924  CYRB   74.7200   -94.9700
# 48216           Thule A. B.      GL     QS  04202  BGTL   76.5333   -68.7500
# 48634          Danmarkshavn      GL     UO  04320  BGDH   76.7667   -18.6667
# 49608              Isachsen      CA     NU  71074  CWIC   78.7900  -103.5500
# 49995        Eureka Airport      CA     NU  71917  CWEU   79.9900   -85.8100
#
#        elevation                   timezone monthly_start monthly_end  \
# 328          6.0           Australia/Hobart    1950-01-01  2022-01-01
# 733         44.0            Pacific/Chatham    1950-01-01  1993-01-01
# 1535        37.0       America/Punta_Arenas    1967-01-01  2021-01-01
# 1903        16.0  America/Argentina/Ushuaia    1950-01-01  2021-01-01
# 2264        13.0  America/Argentina/Ushuaia    1975-01-01  2021-01-01
# ...          ...                        ...           ...         ...
# 48186       68.0           America/Resolute    1947-01-01  2022-01-01
# 48216       77.0              America/Thule    1951-01-01  2022-01-01
# 48634       11.0            America/Godthab    1958-01-01  2022-01-01
# 49608       58.0      America/Cambridge_Bay    1948-01-01  2021-01-01
# 49995       83.0       America/Rankin_Inlet    1947-01-01  2021-01-01
#
#            distance
# 328    55966.607793
# 733    35115.815359
# 1535   10037.814775
# 1903   49022.832059
# 2264   27619.542378
# ...             ...
# 48186  31146.766351
# 48216  52283.268796
# 48634  27270.976403
# 49608  25261.466284
# 49995  15687.195750
#
# [1315 rows x 12 columns]

# %%
loc_df[loc_df[country] == 'IT']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 loc_df[loc_df[country] == 'IT']
#
# NameError: name 'country' is not defined

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 2.4 MB/s eta 0:00:00
# Collecting branca>=0.6.0
#   Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Collecting xyzservices
#   Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from requests->folium) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/noedebrois/opt/anaconda3/envs/VEnvTestPython_3_8_13/lib/python3.8/site-packages (from requests->folium) (2.0.4)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.1 folium-0.15.1 xyzservices-2023.10.1

# %%
import folium

lati_list = list(loc_df["latitude"])
long_list = list(loc_df["longitude"])
m = folium.Map(location=[0, 10], zoom_start=2)

radius = 10000
sum=0
for lat,long in zip(lati_list,long_list):
    sum+=1
    folium.Circle(
        location=[lat,long],
        radius=radius,
        color="black",
        weight=1,
        fill_opacity=0.6,
        opacity=1,
        fill_color="blue",
        fill=False,  # gets overridden by fill_color
        popup="{} meters".format(radius),
        tooltip="I am in meters",
    ).add_to(m)
print(sum)
m
# Out:
# 1315
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cf1327153ef9df2e4f8fa214486f73e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cf1327153ef9df2e4f8fa214486f73e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cf1327153ef9df2e4f8fa214486f73e = L.map(
#                 &quot;map_3cf1327153ef9df2e4f8fa214486f73e&quot;,
#                 {
#                     center: [0.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_717fea05321ff09139b1264c8eeb4b69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_717fea05321ff09139b1264c8eeb4b69.addTo(map_3cf1327153ef9df2e4f8fa214486f73e);
#
#
#             var circle_2c760e6f0129146f506a945ac4b4a683 = L.circle(
#                 [-54.5, 158.9],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3cf1327153ef9df2e4f8fa214486f73e);
#
#
#         var popup_759a88836e48eeb6619328661dc29f78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8be4dfe885961209944d0f2ea54499b6 = $(`&lt;div id=&quot;html_8be4dfe885961209944d0f2ea54499b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10000 meters&lt;/div&gt;`)[0];
#                 popup_759a88836e48eeb6619328661dc29f78.setContent(html_8be4dfe885961209944d0f2ea54499b6);
#
#
#
#         circle_2c760e6f0129146f506a945ac4b4a683.bindPopup(popup_759a88836e48eeb6619328661dc29f78)
#         ;
#
#
#
#
#             circle_2c760e6f0129146f506a945ac4b4a683.bindTooltip(
#                 `&lt;div&gt;
#                      I am in meters
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_024a345fa3e78bea413d12f2bb39010a = L.circle(
#                 [-43.95, -176.5667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3cf1327153ef9df2e4f8fa214486f73e);
#
#
#         var popup_7e0e777ccfff4092213bac87de23672c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5f104bfc00786e02f73c58edd500548 = $(`&lt;div id=&quot;html_f5f104bfc00786e02f73c58edd500548&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10000 meters&lt;/div&gt;`)[0];
#                 popup_7e0e777ccfff4092213bac87de23672c.setContent(html_f5f104bfc00786e02f73c58edd500548);
#
#
#
#         circle_024a345fa3e78bea413d12f2bb39010a.bindPopup(popup_7e0e777ccfff4092213bac87de23672c)
#         ;
#
#
#
#
#             circle_024a345fa3e78bea413d12f2bb39010a.bindTooltip(
#                 `&lt;div&gt;
#                      I am in meters
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_e2799c4e97f6486bef2af33701cfc148 = L.circle(
#                 [-53.0, -70.85],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3cf1327153ef9df2e4f8fa214486f73e);
#
#
#         var popup_8d8c472512544a0219f8da6c6e25ee97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6eb6e8fb557c28612da7d240d6c3afa9 = $(`&lt;div id=&quot;html_6eb6e8fb557c28612da7d240d6c3afa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10000 meters&lt;/div&gt;`)[0];
#                 popup_8d8c472512544a0219f8da6c6e25ee97.setContent(html_6eb6e8fb557c28612da7d240d6c3afa9);
#
#
#
#         circle_e2799c4e97f6486bef2af33701cfc148.bindPopup(popup_8d8c472512544a0219f8da6c6e25ee97)
#         ;

# %%
a = loc_df[loc_df.country== "FR"]
print(a,len(a))
# Out:
#                        name country region    wmo  icao  latitude  longitude  \
# 36805               Ajaccio      FR      H  07761  LFKJ   41.9167     8.8000
# 37156  Tarbes Ossun Lourdes      FR      N  07621  LFBT   43.1833     0.0000
# 37157             St-Girons      FR      N  07627  LFCG   43.0000     1.1000
# 37522                  Nice      FR      U  07690  LFMN   43.6500     7.2000
# 37873   Bordeaux / Merignac      FR      B  07510  LFBD   44.8333    -0.7000
# 38234               Limoges      FR     HV  07434  LFBL   45.8667     1.1833
# 38236      Clermont-Ferrand      FR      C  07460  LFLC   45.7833     3.1667
# 38592              Poitiers      FR      T  07335  LFBI   46.5833     0.3167
# 38593                 Tours      FR      F  07240  LFOT   47.4500     0.7167
# 38949                Rennes      FR      E  07130  LFRN   48.0667    -1.7333
# 38955                Troyes      FR      G  07168  LFQB   48.3333     4.0167
# 39310                  Caen      FR      P  07027  LFRK   49.1833    -0.4500
# 39671             Abbeville      FR      S  07005  LFOI   50.1333     1.8333
#
#        elevation      timezone monthly_start monthly_end      distance
# 36805        6.0  Europe/Paris    1944-01-01  2022-01-01  18954.854695
# 37156      379.0  Europe/Paris    1973-01-01  2022-01-01  20382.030054
# 37157      414.0  Europe/Paris    1973-01-01  2022-01-01   8132.281640
# 37522        4.0  Europe/Paris    1945-01-01  2022-01-01  42095.735424
# 37873       49.0  Europe/Paris    1901-01-01  2022-01-01  30026.673607
# 38234      396.0  Europe/Paris    1973-01-01  2022-01-01  20509.682497
# 38236      332.0  Europe/Paris    1973-01-01  2022-01-01  27332.444817
# 38592      129.0  Europe/Paris    1973-01-01  2022-01-01  52232.393634
# 38593      108.0  Europe/Paris    1973-01-01  2022-01-01  54419.090201
# 38949       37.0  Europe/Paris    1944-01-01  2022-01-01  21172.231498
# 38955      118.0  Europe/Paris    1975-01-01  2022-01-01  37081.957757
# 39310       78.0  Europe/Paris    1973-01-01  2022-01-01  38589.012707
# 39671       74.0  Europe/Paris    1940-01-01  2022-01-01  19007.090344   13

# %%
lati_list = list(loc_df["latitude"])
long_list = list(loc_df["longitude"])

lati_list_pays = list(a["latitude"])
long_list_pays = list(a["longitude"])

plt.plot(long_list,lati_list,'x',long_list_pays,lati_list_pays,'rx')

data = Daily(Point(50.5, 1.7), start, end)
data = data.fetch()

#path = Path(f"/Users/simontrottier/Documents/Polimi/Nonparametric stat/stat_project/Data/zzz.csv")
#data.to_csv(path)

# %%
def jours(mois):
    if mois==1:
        return 31
    if mois==2:
        return 28
    if mois==3:
        return 31
    if mois==4:
        return 30
    if mois==5:
        return 31
    if mois==6:
        return 30
    if mois==7:
        return 31
    if mois==8:
        return 31
    if mois==9:
        return 30
    if mois==10:
        return 31
    if mois==11:
        return 30
    if mois==12:
        return 31

# %%
# Dico
from pathlib import Path

lati_long_list = loc_df[["latitude", "longitude","name"]]
dico = dict()

path_dir = Path(f"/Users/noedebrois/Desktop/STAT_PROJET/NonParametricStatsProject/BDD_DAILY_WORLD")
os.mkdir(path_dir)

for idx in tqdm(range(len(lati_long_list))):
    try :
        a=tuple(lati_long_list.iloc[idx])[2].replace("/","_")
        # Set time period
        start = datetime(1978, 1, 1)
        end = datetime(2022, 12, 31)        
        data = Daily(Point(tuple(lati_long_list.iloc[idx])[0], tuple(lati_long_list.iloc[idx])[1]), start, end)
        data = data.fetch()
        # data = data.resample("M").mean()
        data.drop(["tsun",'wspd'], axis=1, inplace=True)
        path = Path(f"/Users/noedebrois/Desktop/STAT_PROJET/NonParametricStatsProject/BDD_DAILY_WORLD/Data_{a}.csv")
        data.to_csv(path)
    except :
        print(idx)
# Out:
#   0%|          | 1/1315 [00:00<17:46,  1.23it/s]Warning: Cannot load daily/93986.csv.gz from https://bulk.meteostat.net/v2/
#   1%|          | 11/1315 [00:12<17:20,  1.25it/s] Warning: Cannot load daily/93844.csv.gz from https://bulk.meteostat.net/v2/
#   3%|▎         | 35/1315 [00:31<14:51,  1.44it/s]Warning: Cannot load daily/87696.csv.gz from https://bulk.meteostat.net/v2/
#   3%|▎         | 43/1315 [00:40<19:55,  1.06it/s]Warning: Cannot load daily/93012.csv.gz from https://bulk.meteostat.net/v2/
#   3%|▎         | 44/1315 [00:40<16:12,  1.31it/s]Warning: Cannot load daily/85657.csv.gz from https://bulk.meteostat.net/v2/
#   6%|▌         | 74/1315 [06:11<31:28:20, 91.30s/it]
# 73
#   9%|▉         | 124/1315 [07:33<34:31,  1.74s/it]  Warning: Cannot load daily/94482.csv.gz from https://bulk.meteostat.net/v2/
#  10%|▉         | 126/1315 [07:37<36:31,  1.84s/it]Warning: Cannot load daily/91952.csv.gz from https://bulk.meteostat.net/v2/
#  11%|█         | 145/1315 [08:06<1:09:38,  3.57s/it]Warning: Cannot load daily/68240.csv.gz from https://bulk.meteostat.net/v2/
#  13%|█▎        | 168/1315 [08:51<34:34,  1.81s/it]  Warning: Cannot load daily/86017.csv.gz from https://bulk.meteostat.net/v2/
#  15%|█▍        | 193/1315 [09:21<24:20,  1.30s/it]Warning: Cannot load daily/83554.csv.gz from https://bulk.meteostat.net/v2/
#  15%|█▌        | 200/1315 [09:29<25:04,  1.35s/it]Warning: Cannot load daily/67774.csv.gz from https://bulk.meteostat.net/v2/
#  16%|█▋        | 215/1315 [09:46<19:01,  1.04s/it]Warning: Cannot load daily/91941.csv.gz from https://bulk.meteostat.net/v2/
#  18%|█▊        | 234/1315 [10:13<22:48,  1.27s/it]Warning: Cannot load daily/84677.csv.gz from https://bulk.meteostat.net/v2/
#  18%|█▊        | 242/1315 [10:19<14:10,  1.26it/s]Warning: Cannot load daily/96845.csv.gz from https://bulk.meteostat.net/v2/
#  19%|█▉        | 252/1315 [15:35<27:17:43, 92.44s/it]
# 251
# Warning: Cannot load daily/66305.csv.gz from https://bulk.meteostat.net/v2/
#  21%|██        | 274/1315 [15:50<10:48,  1.61it/s]   Warning: Cannot load daily/97385.csv.gz from https://bulk.meteostat.net/v2/
#  23%|██▎       | 299/1315 [16:10<12:50,  1.32it/s]Warning: Cannot load daily/92010.csv.gz from https://bulk.meteostat.net/v2/
#  24%|██▎       | 311/1315 [16:18<12:06,  1.38it/s]Warning: Cannot load daily/84435.csv.gz from https://bulk.meteostat.net/v2/
#  24%|██▍       | 317/1315 [16:23<12:58,  1.28it/s]Warning: Cannot load daily/63985.csv.gz from https://bulk.meteostat.net/v2/
#  25%|██▍       | 327/1315 [16:37<26:52,  1.63s/it]Warning: Cannot load daily/64246.csv.gz from https://bulk.meteostat.net/v2/
#  27%|██▋       | 351/1315 [16:54<11:54,  1.35it/s]
# 350
#  27%|██▋       | 353/1315 [16:56<11:57,  1.34it/s]Warning: Cannot load daily/WIPK0.csv.gz from https://bulk.meteostat.net/v2/
#  30%|██▉       | 388/1315 [17:28<11:08,  1.39it/s]Warning: Cannot load daily/61866.csv.gz from https://bulk.meteostat.net/v2/
#  30%|██▉       | 391/1315 [17:30<12:17,  1.25it/s]Warning: Cannot load daily/64545.csv.gz from https://bulk.meteostat.net/v2/
#  31%|███▏      | 413/1315 [17:48<11:18,  1.33it/s]Warning: Cannot load daily/81010.csv.gz from https://bulk.meteostat.net/v2/
#  33%|███▎      | 440/1315 [18:09<10:39,  1.37it/s]Warning: Cannot load daily/81208.csv.gz from https://bulk.meteostat.net/v2/
#  38%|███▊      | 497/1315 [19:05<13:17,  1.03it/s]
# 496
#  44%|████▎     | 575/1315 [20:21<10:26,  1.18it/s]
# 574
#  46%|████▌     | 600/1315 [20:47<13:01,  1.09s/it]Warning: Cannot load daily/PGTI0.csv.gz from https://bulk.meteostat.net/v2/
#  48%|████▊     | 626/1315 [21:11<11:09,  1.03it/s]Warning: Cannot load daily/MMTB0.csv.gz from https://bulk.meteostat.net/v2/
#  52%|█████▏    | 683/1315 [22:07<11:52,  1.13s/it]Warning: Cannot load daily/48926.csv.gz from https://bulk.meteostat.net/v2/
#  53%|█████▎    | 697/1315 [22:26<17:16,  1.68s/it]Warning: Cannot load daily/41006.csv.gz from https://bulk.meteostat.net/v2/
#  61%|██████    | 802/1315 [24:25<10:54,  1.28s/it]Warning: Cannot load daily/40986.csv.gz from https://bulk.meteostat.net/v2/
#  63%|██████▎   | 835/1315 [25:18<09:10,  1.15s/it]Warning: Cannot load daily/40976.csv.gz from https://bulk.meteostat.net/v2/
#  66%|██████▋   | 874/1315 [26:13<08:42,  1.18s/it]Warning: Cannot load daily/LMMM0.csv.gz from https://bulk.meteostat.net/v2/
#  73%|███████▎  | 955/1315 [28:29<17:52,  2.98s/it]Warning: Cannot load daily/08302.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08301.csv.gz from https://bulk.meteostat.net/v2/
#  76%|███████▌  | 1002/1315 [29:43<08:33,  1.64s/it]Warning: Cannot load daily/08180.csv.gz from https://bulk.meteostat.net/v2/
#  78%|███████▊  | 1021/1315 [30:26<13:58,  2.85s/it]Warning: Cannot load daily/08161.csv.gz from https://bulk.meteostat.net/v2/
#  83%|████████▎ | 1088/1315 [32:25<09:35,  2.53s/it]Warning: Cannot load daily/16044.csv.gz from https://bulk.meteostat.net/v2/
#  86%|████████▌ | 1126/1315 [33:43<13:36,  4.32s/it]Warning: Cannot load daily/11722.csv.gz from https://bulk.meteostat.net/v2/
#  87%|████████▋ | 1148/1315 [34:23<05:06,  1.84s/it]Warning: Cannot load daily/03952.csv.gz from https://bulk.meteostat.net/v2/
#  87%|████████▋ | 1150/1315 [34:30<07:55,  2.88s/it]Warning: Cannot load daily/12425.csv.gz from https://bulk.meteostat.net/v2/
#  88%|████████▊ | 1155/1315 [34:47<11:11,  4.20s/it]Warning: Cannot load daily/CWJG0.csv.gz from https://bulk.meteostat.net/v2/
#  88%|████████▊ | 1158/1315 [34:51<06:16,  2.40s/it]Warning: Cannot load daily/03586.csv.gz from https://bulk.meteostat.net/v2/
#  89%|████████▉ | 1176/1315 [35:32<05:03,  2.18s/it]Warning: Cannot load daily/03970.csv.gz from https://bulk.meteostat.net/v2/
#  96%|█████████▋| 1267/1315 [38:19<01:16,  1.60s/it]Warning: Cannot load daily/PACL0.csv.gz from https://bulk.meteostat.net/v2/
#  97%|█████████▋| 1273/1315 [38:30<01:11,  1.71s/it]Warning: Cannot load daily/02879.csv.gz from https://bulk.meteostat.net/v2/
#  99%|█████████▊| 1298/1315 [39:06<00:28,  1.66s/it]Warning: Cannot load daily/04340.csv.gz from https://bulk.meteostat.net/v2/
# 100%|██████████| 1315/1315 [39:31<00:00,  1.80s/it]

# %%
data
# Out:
#             tavg  tmin  tmax  prcp   snow   wdir  wpgt    pres
# time
# 1978-01-01 -43.2 -44.3 -42.7   0.0  280.0    NaN   NaN     NaN
# 1978-01-02 -43.9 -45.1 -43.0   0.0  280.0    NaN   NaN     NaN
# 1978-01-03 -44.3 -45.7 -43.8   0.0  260.0    NaN   NaN     NaN
# 1978-01-04 -44.8 -45.6 -37.2   0.0  260.0    NaN   NaN     NaN
# 1978-01-05 -37.8 -43.1 -34.6   0.2  260.0    NaN   NaN     NaN
# ...          ...   ...   ...   ...    ...    ...   ...     ...
# 2022-12-27 -37.0 -39.6 -32.4   0.0    NaN   81.0   NaN  1015.0
# 2022-12-28 -36.5 -39.0 -34.0   0.0    NaN   99.0   NaN  1016.8
# 2022-12-29 -38.5 -41.0 -36.5   0.0    NaN  102.0   NaN  1019.0
# 2022-12-30 -38.1 -39.9 -35.8   0.0    NaN   78.0   NaN  1022.3
# 2022-12-31 -38.2 -40.0 -36.7   0.0    NaN   62.0   NaN  1022.2
#
# [16436 rows x 8 columns]
